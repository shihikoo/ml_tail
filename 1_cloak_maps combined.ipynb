# %%
import numpy as np
import pandas as pd
import ipyplot

# %%
main_plot_path = "idl_data/output_300sec/plots/sp0/maps_ss27/"

non_sort_map_path = main_plot_path + 'non_sort_map'
# hemi_sort_map_path = main_plot_path+"hemi_sort_map"
kp_sort_map_path = main_plot_path+'kp_sort_map'
# bx_sort_map_path = main_plot_path+'bx_sort_map'

start_time = '20130101'
end_time = '20210101'
 
grid_str = "grid_01"
direction_str = "both"
correction_flag_str = ''

ratio_type = "ratio"

# %% [markdown]
# # All region maps in different projections

# %%
images_array = [ non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"]

ipyplot.plot_images(images_array, img_width=400)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-CwZr4h4o28ZfW4xpriwow4 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-CwZr4h4o28ZfW4xpriwow4 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-CwZr4h4o28ZfW4xpriwow4 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-CwZr4h4o28ZfW4xpriwow4:checked ~ #ipyplot-html-viewer-textarea-CwZr4h4o28ZfW4xpriwow4 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-CwZr4h4o28ZfW4xpriwow4:checked + #ipyplot-html-viewer-label-CwZr4h4o28ZfW4xpriwow4:after {
# ...

# %% [markdown]
# ## Different energy  ranges

# %%
images_array = [                     non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_0_30__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                    ,
non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_30_100__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                    ,
non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_100_500__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                                    ,                non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_500_1000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_1000_3000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                       ,              non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_3000_10000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"  
                , non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_10000_60000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"       
]

ipyplot.plot_images(images_array, img_width=222)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-XqF8vpniAU9kWratV9APsX {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-XqF8vpniAU9kWratV9APsX {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-XqF8vpniAU9kWratV9APsX {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-XqF8vpniAU9kWratV9APsX:checked ~ #ipyplot-html-viewer-textarea-XqF8vpniAU9kWratV9APsX {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-XqF8vpniAU9kWratV9APsX:checked + #ipyplot-html-viewer-label-XqF8vpniAU9kWratV9APsX:after {
# ...

# %% [markdown]
# ### Fine energy ranges

# %%
images_array = [ non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_0_30__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                ,     non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_30_100__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                ,     non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_100_300__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                ,                non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_300_500__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_500_1000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_1000_2000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_2000_3000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_3000_5000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_5000_10000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                , non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_10000_60000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"       
]

ipyplot.plot_images(images_array, img_width=222)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-LnQu9DdENmg3bxZydx5ZKd {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-LnQu9DdENmg3bxZydx5ZKd {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-LnQu9DdENmg3bxZydx5ZKd {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-LnQu9DdENmg3bxZydx5ZKd:checked ~ #ipyplot-html-viewer-textarea-LnQu9DdENmg3bxZydx5ZKd {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-LnQu9DdENmg3bxZydx5ZKd:checked + #ipyplot-html-viewer-label-LnQu9DdENmg3bxZydx5ZKd:after {
# ...

# %% [markdown]
# # -----------------------------------------------------------------------------------

# %% [markdown]
# ## kp impacts

# %%
images_array = [ kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_"+direction_str+"/events/2d/Kplt_2_"+direction_str+"_en_0_30__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                , kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_"+direction_str+"/events/2d/Kpge_2_"+direction_str+"_en_0_30__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                ,     kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_"+direction_str+"/events/2d/Kplt_2_"+direction_str+"_en_30_100__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                ,     kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_"+direction_str+"/events/2d/Kpge_2_"+direction_str+"_en_30_100__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                ,     kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_"+direction_str+"/events/2d/Kplt_2_"+direction_str+"_en_100_500__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                ,     kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_"+direction_str+"/events/2d/Kpge_2_"+direction_str+"_en_100_500__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                ,                kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_"+direction_str+"/events/2d/Kplt_2_"+direction_str+"_en_500_1000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                ,                kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_"+direction_str+"/events/2d/Kpge_2_"+direction_str+"_en_500_1000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                     ,          kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_"+direction_str+"/events/2d/Kplt_2_"+direction_str+"_en_1000_3000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                     ,          kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_"+direction_str+"/events/2d/Kpge_2_"+direction_str+"_en_1000_3000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"

                       ,              kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_"+direction_str+"/events/2d/Kplt_2_"+direction_str+"_en_3000_10000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"  
                                       ,              kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_"+direction_str+"/events/2d/Kpge_2_"+direction_str+"_en_3000_10000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"  

                , kp_sort_map_path+"/kp_lt_2/"+grid_str+"/Kplt_2_"+direction_str+"/events/2d/Kplt_2_"+direction_str+"_en_10000_60000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                , kp_sort_map_path+"/kp_ge_2/"+grid_str+"/Kpge_2_"+direction_str+"/events/2d/Kpge_2_"+direction_str+"_en_10000_60000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"       

]

ipyplot.plot_images(images_array, img_width=220)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-NBGyhKPdTYpdbBDXd3QM8z {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-NBGyhKPdTYpdbBDXd3QM8z {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-NBGyhKPdTYpdbBDXd3QM8z {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-NBGyhKPdTYpdbBDXd3QM8z:checked ~ #ipyplot-html-viewer-textarea-NBGyhKPdTYpdbBDXd3QM8z {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-NBGyhKPdTYpdbBDXd3QM8z:checked + #ipyplot-html-viewer-label-NBGyhKPdTYpdbBDXd3QM8z:after {
# ...

# %% [markdown]
# ## Solar wind velocity impacts on the convection maps

# %%
images_array = [ non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_0_30_swV_0_450_"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                ,                 non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_0_30_swV_450_900_"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                ,     non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_30_100_swV_0_450_"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                ,     non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_30_100_swV_450_900_"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                ,                non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_100_500_swV_0_450_"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                ,                non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_100_500_swV_450_900_"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"

                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_500_1000_swV_0_450_"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_500_1000_swV_450_900_"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_1000_3000_swV_0_450_"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_1000_3000_swV_450_900_"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_3000_5000_swV_0_450_"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_3000_5000_swV_450_900_"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_5000_10000_swV_0_450_"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_5000_10000_swV_450_900_"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                , non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_10000_60000_swV_0_450_"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"     
                                , non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_10000_60000_swV_450_900_"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"       

]

ipyplot.plot_images(images_array, img_width=220)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-hGKgxUjkLUvbPABK9FmibN {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-hGKgxUjkLUvbPABK9FmibN {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-hGKgxUjkLUvbPABK9FmibN {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-hGKgxUjkLUvbPABK9FmibN:checked ~ #ipyplot-html-viewer-textarea-hGKgxUjkLUvbPABK9FmibN {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-hGKgxUjkLUvbPABK9FmibN:checked + #ipyplot-html-viewer-label-hGKgxUjkLUvbPABK9FmibN:after {
# ...

# %% [markdown]
# ## Solar wind pressure impacts on the convection maps

# %%
images_array = [ non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_0_30_swP_0_2__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                ,                 non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_0_30_swP_2_20__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                ,     non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_30_100_swP_0_2__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                ,     non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_30_100_swP_2_20__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                ,     non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_100_500_swP_0_2__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                                ,     non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_100_500_swP_2_20__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_500_1000_swP_0_2__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_500_1000_swP_2_20__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_1000_3000_swP_0_2__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_1000_3000_swP_2_20__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_3000_5000_swP_0_2__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_3000_5000_swP_2_20__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_5000_10000_swP_0_2__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_5000_10000_swP_2_20__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                , non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_10000_60000_swP_0_2__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"     
                                , non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/"+direction_str+"_en_10000_60000_swP_2_20__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"       
]

ipyplot.plot_images(images_array, img_width=222)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-4L6ZTZCuCEAT9ogNULpLt8 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-4L6ZTZCuCEAT9ogNULpLt8 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-4L6ZTZCuCEAT9ogNULpLt8 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-4L6ZTZCuCEAT9ogNULpLt8:checked ~ #ipyplot-html-viewer-textarea-4L6ZTZCuCEAT9ogNULpLt8 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-4L6ZTZCuCEAT9ogNULpLt8:checked + #ipyplot-html-viewer-label-4L6ZTZCuCEAT9ogNULpLt8:after {
# ...

# %% [markdown]
# ## Storm impacts

# %%
images_array = [ non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/nonstorm_time_"+direction_str+"_en_0_30__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                ,                 non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/storm_time_"+direction_str+"_en_0_30__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                ,     non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/nonstorm_time_"+direction_str+"_en_30_100__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                ,     non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/storm_time_"+direction_str+"_en_30_100__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                ,     non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/nonstorm_time_"+direction_str+"_en_100_300__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                                ,     non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/storm_time_"+direction_str+"_en_100_300__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                ,                non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/nonstorm_time_"+direction_str+"_en_300_500__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                ,                non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/storm_time_"+direction_str+"_en_300_500__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/nonstorm_time_"+direction_str+"_en_500_1000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/storm_time_"+direction_str+"_en_500_1000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/nonstorm_time_"+direction_str+"_en_1000_2000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/storm_time_"+direction_str+"_en_1000_2000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/nonstorm_time_"+direction_str+"_en_2000_3000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/storm_time_"+direction_str+"_en_2000_3000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/nonstorm_time_"+direction_str+"_en_3000_5000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/storm_time_"+direction_str+"_en_3000_5000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/nonstorm_time_"+direction_str+"_en_5000_10000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                                     ,          non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/storm_time_"+direction_str+"_en_5000_10000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"
                , non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/nonstorm_time_"+direction_str+"_en_10000_60000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"     
                                , non_sort_map_path+"/"+grid_str+"/"+direction_str+"/events/2d/storm_time_"+direction_str+"_en_10000_60000__"+ratio_type+"_"+start_time+"_to_"+end_time+"_MLT_vs_L.png"       
]

ipyplot.plot_images(images_array, img_width=222)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-5hK4rWgbEenCMqMJqD6YAv {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-5hK4rWgbEenCMqMJqD6YAv {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-5hK4rWgbEenCMqMJqD6YAv {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-5hK4rWgbEenCMqMJqD6YAv:checked ~ #ipyplot-html-viewer-textarea-5hK4rWgbEenCMqMJqD6YAv {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-5hK4rWgbEenCMqMJqD6YAv:checked + #ipyplot-html-viewer-label-5hK4rWgbEenCMqMJqD6YAv:after {
# ...
